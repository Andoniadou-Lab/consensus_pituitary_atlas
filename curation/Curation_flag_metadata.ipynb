# %% [markdown]
# <a href="https://colab.research.google.com/github/Andoniadou-Lab/consensus_pituitary_atlas/blob/main/Curation_flag_metadata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mounting Drive onto colab

# %%
#mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/pituitary_atlas/source_table/pituitary_atlas.xlsx')

# %% [markdown]
# # Sample wrong sex

# %%
df[df['Sample_wrong_sex']==1]
# Out:
#            GEO       SRA_ID                                 Name Conditions  \
# 66  GSM7821518  SRX21986110  Female Control Pituitary 15 wk rep2     normal
# 68  GSM7821520  SRX21986112    Male Control Pituitary 15 wk rep2     normal
#
#     Normal Background  Sorted               Author                     DOI  \
# 66       1    FVB/Ant       0  Miles et al. (2023)  10.1210/endocr/bqad191
# 68       1    FVB/Ant       0  Miles et al. (2023)  10.1210/endocr/bqad191
#
#         Age  ...  filtering_junk median_cellassign_prob  most_recent_workflow  \
# 66  15 week  ...             1.0                    1.0                v_0.01
# 68  15 week  ...             1.0                    1.0                v_0.01
#
#    n_cells  processed_atac passed_qc_tcc tcc_pseudobulked Core  \
# 66  1085.0             0.0           1.0           v_0.01  1.0
# 68   560.0             0.0          -1.0              NaN  1.0
#
#                            Notes 1 Notes 2
# 66    Incorrect sex, actually male     NaN
# 68  Incorrect sex, actually female     NaN
#
# [2 rows x 41 columns]

# %% [markdown]
# # Sample missing sex

# %%
df[df['Sample_missing_sex']==1]
# Out:
#             GEO       SRA_ID  \
# 101  GSM4597450   SRX8497092
# 102  GSM4597452   SRX8497093
# 103  GSM4597453   SRX8497094
# 104  GSM4958650   SRX9637224
# 119  GSM7864906  SRX22219345
# 120  GSM7864907  SRX22219346
# 183  GSM8628052  SRX26708357
# 261  GSM7663099  SRX21168593
# 262  GSM7663100  SRX21168594
# 263  GSM7663101  SRX21168595
# 264  GSM7663102  SRX21168596
#
#                                                   Name  \
# 101                                  Sox9iresCreERT2/+
# 102                  Sox9iresCreERT2/+;Sox2fl/+;p27-/-
# 103                           Sox9iresCreERT2/+;p27-/-
# 104  Single cell RNA-seq - adult tdTomato MPs enric...
# 119  Retinoic acid reporter mouse (RARE-LacZ JAX st...
# 120  Two pooled e14.5 pituitary glands from C57BL6 ...
# 183  Two pooled e14.5 pituitary glands from C57BL6 ...
# 261               Pituitary, young, sample1, scRNA-seq
# 262                Pituitary, aged, sample1, scRNA-seq
# 263               Pituitary, young, sample2, scRNA-seq
# 264                Pituitary, aged, sample2, scRNA-seq
#
#                                          Conditions  Normal Background  \
# 101                               Sox9iresCreERT2/+       1    missing
# 102                                            S2CK       0    missing
# 103                                         P27NULL       0    missing
# 104  Hic1CreERT2/CreERT2;Rosa26LSLtdTomato/tdTomato       1    C57BL/6
# 119                                          normal       1    C57BL/6
# 120                                          normal       1    C57BL/6
# 183                                        Nxn -/-        0    C57BL/6
# 261                                          normal       1    C57BL/6
# 262                                          normal       1    C57BL/6
# 263                                          normal       1    C57BL/6
# 264                                          normal       1    C57BL/6
#
#      Sorted                        Author                         DOI  \
# 101       0     Moncho-Amor et al. (2021)     10.1073/pnas.2017115118
# 102       0     Moncho-Amor et al. (2021)     10.1073/pnas.2017115118
# 103       0     Moncho-Amor et al. (2021)     10.1073/pnas.2017115118
# 104       1         Bastedo et al. (2024)  10.1186/s12987-024-00535-7
# 119       0  Martinez-Mayer et al. (2024)  10.1186/s13073-024-01347-y
# 120       0  Martinez-Mayer et al. (2024)  10.1186/s13073-024-01347-y
# 183       0      Brinkmeier et al. (2025)         10.1093/hmg/ddaf032
# 261       0             Wei et al. (2025)                         NaN
# 262       0             Wei et al. (2025)                         NaN
# 263       0             Wei et al. (2025)                         NaN
# 264       0             Wei et al. (2025)                         NaN
#
#            Age  ...  filtering_junk median_cellassign_prob  \
# 101    3 month  ...             1.0               1.000000
# 102    3 month  ...             1.0               1.000000
# 103    3 month  ...             1.0               1.000000
# 104     8 week  ...             1.0               1.000000
# 119      e12.5  ...             1.0               1.000000
# 120      e14.5  ...             1.0               0.973119
# 183      e14.5  ...             1.0               0.991270
# 261   6 months  ...             1.0               1.000000
# 262  24 months  ...             1.0               1.000000
# 263   6 months  ...             1.0               1.000000
# 264  24 months  ...             1.0               1.000000
#
#      most_recent_workflow  n_cells  processed_atac passed_qc_tcc  \
# 101                v_0.01   1576.0             0.0           1.0
# 102                v_0.01   3262.0             0.0           1.0
# 103                v_0.01   3762.0             0.0           1.0
# 104                v_0.01   5535.0             0.0           1.0
# 119                v_0.01   1529.0             0.0           1.0
# 120                v_0.01   7909.0             0.0           1.0
# 183                v_0.01   4600.0             NaN           1.0
# 261                v_0.01  10116.0             NaN           NaN
# 262                v_0.01   7710.0             NaN           NaN
# 263                v_0.01   7736.0             NaN           NaN
# 264                v_0.01   6507.0             NaN           NaN
#
#     tcc_pseudobulked Core                                            Notes 1  \
# 101           v_0.01  1.0                     intermediate lobe only; no sex
# 102           v_0.01  1.0                     intermediate lobe only; no sex
# 103           v_0.01  1.0  intermediate lobe only; no sex - probably bit ...
# 104           v_0.01  1.0                                        missing sex
# 119           v_0.01  1.0                       V2 actually, not V3 ; no sex
# 120           v_0.01  1.0                                             no sex
# 183           v_0.01  1.0                                        missing sex
# 261              NaN  1.0                                        missing sex
# 262              NaN  1.0                                        missing sex
# 263              NaN  1.0                                        missing sex
# 264              NaN  1.0                                        missing sex
#
#     Notes 2
# 101     NaN
# 102     NaN
# 103     NaN
# 104     NaN
# 119     NaN
# 120     NaN
# 183     NaN
# 261     NaN
# 262     NaN
# 263     NaN
# 264     NaN
#
# [11 rows x 41 columns]

# %% [markdown]
# # Sample wrong kit

# %%
df[df['Sample_wrong_barcode_kit']==1]
# Out:
#             GEO       SRA_ID  \
# 54   ERX7593481   ERX7593481
# 55   ERX7593482   ERX7593482
# 56   ERX7593483   ERX7593483
# 57   ERX7593484   ERX7593484
# 58   GSM7664008  SRX21170823
# 59   GSM7664009  SRX21170824
# 60   GSM7664010  SRX21170825
# 92   GSM6723959  SRX18224105
# 109  GSM8435090  SRX25532498
# 110  GSM8435091  SRX25532499
# 119  GSM7864906  SRX22219345
# 162  GSM6845276  SRX18716674
# 163  GSM6845277  SRX18716675
#
#                                                   Name  \
# 54                                              EXT292
# 55                                              EXT293
# 56                                              EXT294
# 57                                              EXT295
# 58                                               Young
# 59                                                 Old
# 60                                            Igha-Cre
# 92                                             AX4days
# 109                                          Prop1 +/+
# 110                                        Prop1 df/df
# 119  Retinoic acid reporter mouse (RARE-LacZ JAX st...
# 162                 p25OE pituitary, 14 week, scRNAseq
# 163                     WT pituitary, 14week, scRNAseq
#
#                              Conditions  Normal                 Background  \
# 54                      GH+/+;R26iDTR/+       1                    C57BL/6
# 55           GHCre/+;R26iDTR/+ ablation       0                    C57BL/6
# 56           GHCre/+;R26iDTR/+ ablation       0                    C57BL/6
# 57                      GH+/+;R26iDTR/+       1                    C57BL/6
# 58                               normal       1                    C57BL/6
# 59                               normal       1                    C57BL/6
# 60   Igha-Cre, ZsGreen+ pituitary cells       1                    C57BL/6
# 92            adrenalectomy_sox9_sorted       0                    C57BL/6
# 109                              normal       1                    missing
# 110                         Prop1 df/df       0                    missing
# 119                              normal       1                    C57BL/6
# 162                               p25OE       0  C57BL/6- B6;CBA-BiTg mice
# 163                              normal       1  C57BL/6- B6;CBA-BiTg mice
#
#      Sorted                        Author                         DOI  \
# 54        0         Laporte et al. (2022)         10.7554/eLife.75742
# 55        0         Laporte et al. (2022)         10.7554/eLife.75742
# 56        0         Laporte et al. (2022)         10.7554/eLife.75742
# 57        0         Laporte et al. (2022)         10.7554/eLife.75742
# 58        0              Li et al. (2023)  10.1016/j.isci.2023.107747
# 59        0              Li et al. (2023)  10.1016/j.isci.2023.107747
# 60        1              Li et al. (2023)  10.1016/j.isci.2023.107747
# 92        1         Rizzoti et al. (2023)      10.1126/sciadv.adf6911
# 109       0          Masser et al. (2024)      10.1210/jendso/bvae146
# 110       0          Masser et al. (2024)      10.1210/jendso/bvae146
# 119       0  Martinez-Mayer et al. (2024)  10.1186/s13073-024-01347-y
# 162       0           Huang et al. (2024)   10.1016/j.neo.2024.101054
# 163       0           Huang et al. (2024)   10.1016/j.neo.2024.101054
#
#                Age  ...  filtering_junk median_cellassign_prob  \
# 54          7 days  ...             1.0               1.000000
# 55          7 days  ...             1.0               1.000000
# 56          7 days  ...             1.0               1.000000
# 57          7 days  ...             1.0               1.000000
# 58      2-3 months  ...             1.0               1.000000
# 59    18-24 months  ...             1.0               1.000000
# 60      4-8 months  ...             1.0               1.000000
# 92   7 to 10 w-old  ...             1.0               1.000000
# 109             P4  ...             1.0               1.000000
# 110             P4  ...             1.0               0.999977
# 119          e12.5  ...             1.0               1.000000
# 162             14  ...             1.0               1.000000
# 163             14  ...             1.0               1.000000
#
#      most_recent_workflow n_cells  processed_atac passed_qc_tcc  \
# 54                 v_0.01  3652.0             0.0           1.0
# 55                 v_0.01  4585.0             0.0           1.0
# 56                 v_0.01  5290.0             0.0           1.0
# 57                 v_0.01  4490.0             0.0           1.0
# 58                 v_0.01  8285.0             0.0           1.0
# 59                 v_0.01  7083.0             0.0           1.0
# 60                 v_0.01   948.0             NaN           1.0
# 92                 v_0.01  1457.0             0.0           1.0
# 109                v_0.01  6097.0             0.0           1.0
# 110                v_0.01  4321.0             0.0           1.0
# 119                v_0.01  1529.0             0.0           1.0
# 162                v_0.01  5457.0             NaN           1.0
# 163                v_0.01  4749.0             NaN           1.0
#
#     tcc_pseudobulked Core                                            Notes 1  \
# 54            v_0.01  1.0  had to correct from v2 to v3 - Not actually mixed
# 55            v_0.01  1.0  had to correct from v2 to v3 - Not actually mixed
# 56            v_0.01  1.0  had to correct from v2 to v3 - Not actually mixed
# 57            v_0.01  1.0  had to correct from v2 to v3 - Not actually mixed
# 58            v_0.01  1.0                       had to correct from v2 to v3
# 59            v_0.01  1.0                       had to correct from v2 to v3
# 60            v_0.01  1.0                       had to correct from v2 to v3
# 92            v_0.01  1.0                           Incorrectnly v3 in paper
# 109           v_0.01  1.0                                V2 actually, not V3
# 110           v_0.01  1.0                                V2 actually, not V3
# 119           v_0.01  1.0                       V2 actually, not V3 ; no sex
# 162           v_0.01  1.0                              Incorrectly v2 on GEO
# 163           v_0.01  1.0                              Incorrectly v2 on GEO
#
#     Notes 2
# 54      NaN
# 55      NaN
# 56      NaN
# 57      NaN
# 58      NaN
# 59      NaN
# 60      NaN
# 92      NaN
# 109     NaN
# 110     NaN
# 119     NaN
# 162     NaN
# 163     NaN
#
# [13 rows x 41 columns]

# %% [markdown]
# # Switched up

# %%
df[df['Sample_switched_up']==1]
# Out:
#            GEO       SRA_ID                                              Name  \
# 97  GSM6212046  SRX15581370  YFP FAC-sorted cells from Tshb-Cre; R26-LSL-eYFP
# 98  GSM6212047  SRX15581371  unsorted total pituitary cells from R26-LSL-eYFP
#
#             Conditions  Normal Background  Sorted                Author  \
# 97  sorted_thyrotropes       1    missing       1  Cheung et al. (2023)
# 98              normal       1    missing       0  Cheung et al. (2023)
#
#                        DOI Age  ...  filtering_junk median_cellassign_prob  \
# 97  10.1210/endocr/bqad076   7  ...             1.0                    1.0
# 98  10.1210/endocr/bqad076   7  ...             1.0                    1.0
#
#     most_recent_workflow n_cells  processed_atac passed_qc_tcc  \
# 97                v_0.01  4257.0             0.0           1.0
# 98                v_0.01  4430.0             0.0           1.0
#
#    tcc_pseudobulked Core                                            Notes 1  \
# 97           v_0.01  1.0  This should be SRX15581371 - celltype proporti...
# 98           v_0.01  1.0  Potentially mixed sex sample. This should be S...
#
#    Notes 2
# 97     NaN
# 98     NaN
#
# [2 rows x 41 columns]

# %% [markdown]
# # Minimal n is 1

# %%
print(df['Author'].unique())
print(df['Author'].nunique())
# Out:
# ['Ruf-Zamojski et al. (2021)' 'Cheung et al. (2018)'
#  'Mayran et al. (2019)' 'Chen et al. (2018)' 'Ho et al. (2020)'
#  'Lopez et al. (2021)' 'Ruggiero-Ruff et al. (2023)'
#  'Vennekens et al. (2021)' 'Laporte et al. (2022)' 'Li et al. (2023)'
#  'Miles et al. (2023)' 'Bohaczuk et al. (2021)' 'Schang et al. (2022)'
#  'Lin et al. (2022)' 'Rizzoti et al. (2023)' 'Cheung et al. (2023)'
#  'Allensworth-James et al. (2021)' 'Moncho-Amor et al. (2021)'
#  'Bastedo et al. (2024)' 'Zhang et al. (2024)' 'Cheung et al. (2020)'
#  'Masser et al. (2024)' 'Qian et al. (2024)'
#  'Martinez-Mayer et al. (2024)' 'Kang et al. (2024)'
#  'Sheridan et al. (2024)' 'Khetchoumian et al. (2024)'
#  'Wang et al. (2024)' 'Huang et al. (2024)' 'De Vriendt et al. (2025)'
#  'Ongaro et al. (2025)' 'Brinkmeier et al. (2025)' 'Miles et al. (2025)'
#  'Rebboah et al. (2025)' 'Cheung et al. (2025)' 'Wei et al. (2025)'
#  'Kover et al. (2025)']
# 37

# %%
print(df[df['Study_minimum_n']<2]['Author'].unique())
print(df[df['Study_minimum_n']<2]['Author'].nunique())
print(df['Author'].nunique())
# Out:
# ['Mayran et al. (2019)' 'Ho et al. (2020)' 'Lopez et al. (2021)'
#  'Li et al. (2023)' 'Miles et al. (2023)' 'Lin et al. (2022)'
#  'Rizzoti et al. (2023)' 'Cheung et al. (2023)'
#  'Moncho-Amor et al. (2021)' 'Bastedo et al. (2024)' 'Zhang et al. (2024)'
#  'Cheung et al. (2020)' 'Masser et al. (2024)'
#  'Martinez-Mayer et al. (2024)' 'Kang et al. (2024)'
#  'Sheridan et al. (2024)' 'Khetchoumian et al. (2024)'
#  'Huang et al. (2024)' 'De Vriendt et al. (2025)'
#  'Brinkmeier et al. (2025)' 'Cheung et al. (2025)' 'Kover et al. (2025)']
# 22
# 37

# %%
#turn these to integers based on the first number character 'Study_Seurat_version', 'Study_CR_version' using regex
df['Study_Seurat_version_int'] = df['Study_Seurat_version'].str.extract('(\d+)').astype('Int64')
df['Study_CR_version_int'] = df['Study_CR_version'].str.extract('(\d+)').astype('Int64')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3412223779.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df['Study_Seurat_version_int'] = df['Study_Seurat_version'].str.extract('(\d+)').astype('Int64')
# /tmp/ipython-input-3412223779.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df['Study_CR_version_int'] = df['Study_CR_version'].str.extract('(\d+)').astype('Int64')

# %%
#dropna
df_versions = df.dropna(subset=['Study_CR_version_int'])

df_versions ['Study_CR_version_int']

df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')
df_versions ['Author_year']


#print where year is > 2023 and ['Study_CR_version_int'] < 5
print(df_versions [(df_versions ['Author_year'].astype('Int64') > 2023) & (df_versions ['Study_CR_version_int'] < 7) & (df_versions ['Study_CR_version_int'] > 2)]['Author'].unique())

#print where year is > 2023 and ['Study_CR_version_int'] < 5
print(df_versions [(df_versions ['Author_year'].astype('Int64') > 2023) & (df_versions ['Study_CR_version_int'] < 7) & (df_versions ['Study_CR_version_int'] > 2)]['Author'].nunique())
# Out:
# ['Masser et al. (2024)' 'Martinez-Mayer et al. (2024)'
#  'Kang et al. (2024)' 'Sheridan et al. (2024)'
#  'Khetchoumian et al. (2024)' 'Huang et al. (2024)'
#  'De Vriendt et al. (2025)' 'Miles et al. (2025)' 'Cheung et al. (2025)'
#  'Wei et al. (2025)']
# 10
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1791246390.py:6: SyntaxWarning: invalid escape sequence '\d'
#   df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')
# /tmp/ipython-input-1791246390.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')

# %%
#dropna
df_versions = df.dropna(subset=['Study_Seurat_version_int'])

df_versions ['Study_Seurat_version_int']

df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')
df_versions ['Author_year']


#print where year is > 2023 and ['Study_CR_version_int'] < 5
print(df_versions [(df_versions ['Author_year'].astype('Int64') > 2023) & (df_versions ['Study_Seurat_version_int'] < 5) & (df_versions ['Study_CR_version_int'] > 2)]['Author'].unique())

#print where year is > 2023 and ['Study_CR_version_int'] < 5
print(df_versions [(df_versions ['Author_year'].astype('Int64') > 2023) & (df_versions ['Study_Seurat_version_int'] < 5) & (df_versions ['Study_CR_version_int'] > 2)]['Author'].nunique())
# Out:
# ['Masser et al. (2024)' 'Martinez-Mayer et al. (2024)'
#  'Sheridan et al. (2024)' 'Khetchoumian et al. (2024)'
#  'Huang et al. (2024)' 'De Vriendt et al. (2025)'
#  'Brinkmeier et al. (2025)']
# 7
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1287390759.py:6: SyntaxWarning: invalid escape sequence '\d'
#   df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')
# /tmp/ipython-input-1287390759.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_versions ['Author_year'] =df_versions ['Author'].str.extract('(\d{4})')

# %%
#how many are control

# %%
df[df["Normal"]==1]
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [212 rows x 43 columns]

# %%
df
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [267 rows x 43 columns]

# %%
df["Conditions"].nunique()
#but remove normal, and organoid and 2 wls
# Out:
# 33

# %%
df[df["Normal"]!=1]["Conditions"].unique()
# Out:
# array(['mt/hGRF', 'stressed', 'high_fat_diet',
#        'GHCre/+;R26iDTR/+ ablation', 'GATAcKO', 'SF1_KO',
#        'adrenalectomy_sox9_sorted', 'gonadectomy_sox9_sorted', 'S2CK',
#        'P27NULL', 'Hesx1Cre_dnRAR', 'Prop1 df/df', 'IREPKO',
#        'Pituitary_TpitHT', 'Pituitary_TpitKO', 'p25OE', 'normal',
#        'Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)',
#        'Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)', 'Nxn -/- ',
#        'FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bKnmn (+/-); Leprtm1Rck (fl/fl)'],
#       dtype=object)

# %%
len(['mt/hGRF', 'stressed', 'high_fat_diet',
       'GHCre/+;R26iDTR/+ ablation', 'GATAcKO', 'KO',
       'adrenalectomy_sox9_sorted', 'gonadectomy_sox9_sorted', 'S2CK',
       'P27NULL', 'Hesx1Cre_dnRAR', 'Prop1 df/df', 'IREPKO',
       'Pituitary_TpitHT', 'Pituitary_TpitKO', 'p25OE', 'normal',
       'Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)',
       'Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)', 'Nxn -/- ',
       'FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bKnmn (+/-); Leprtm1Rck (fl/fl)'])
# Out:
# 21

# %%
conditions = df[df["Normal"]!=1]["Conditions"].unique()
#remove "normal"
conditions = [x for x in conditions if x not in ["normal"]]
print(len(conditions))
# Out:
# 20

# %%
df[df["Normal"]!=1]
# Out:
#              GEO       SRA_ID  \
# 32    GSM4399745   SRX7874739
# 41    GSM4914025   SRX9528565
# 44    GSM7679946  SRX21241800
# 45    GSM7679947  SRX21241801
# 47    ERX4978538   ERX4978538
# 50    ERX4978541   ERX4978541
# 51    ERX4978542   ERX4978542
# 52    ERX4978543   ERX4978543
# 55    ERX7593482   ERX7593482
# 56    ERX7593483   ERX7593483
# 62    GSM7821514  SRX21986106
# 64    GSM7821516  SRX21986108
# 69    GSM7821521  SRX21986113
# 70    GSM7821522  SRX21986114
# 71    GSM7821523  SRX21986115
# 72    GSM7821524  SRX21986116
# 78    GSM5712761  SRX13293487
# 79    GSM5712762  SRX13293488
# 80    GSM5712763  SRX13293489
# 84    GSM5712741  SRX13290060
# 85    GSM5712742  SRX13290061
# 86    GSM5712743  SRX13290062
# 90    GSM5959924  SRX14495688
# 92    GSM6723959  SRX18224105
# 93    GSM6723960  SRX18224106
# 95    GSM6723962  SRX18224108
# 102   GSM4597452   SRX8497093
# 103   GSM4597453   SRX8497094
# 108   GSM4219538   SRX7377166
# 110   GSM8435091  SRX25532499
# 113   GSM8187332  SRX24151434
# 114   GSM8187333  SRX24151435
# 117   GSM8187336  SRX24151438
# 118   GSM8187337  SRX24151439
# 126   GSM7102843  SRX19698101
# 127   GSM7102844  SRX19698100
# 161   GSM6845275  SRX18716673
# 162   GSM6845276  SRX18716674
# 165  ERX13202613  ERX13202613
# 166  ERX13202614  ERX13202614
# 168  ERX12265374  ERX12265374
# 169  ERX12265375  ERX12265375
# 170  ERX12265376  ERX12265376
# 171  ERX12265377  ERX12265377
# 172   GSM8464638  SRX25736219
# 173   GSM8464639  SRX25736220
# 174   GSM8464640  SRX25736221
# 178   GSM8464644  SRX25736225
# 179   GSM8464645  SRX25736226
# 180   GSM8464646  SRX25736227
# 183   GSM8628052  SRX26708357
# 188   GSM8499073  SRX25982298
# 189   GSM8499074  SRX25982301
# 190   GSM8499075  SRX25982300
# 191   GSM8499076  SRX25982299
#
#                                                   Name  \
# 32                       mt/hGRF transgenic-8wk-female
# 41                                    Pituitary_Stress
# 44                                               HFD 1
# 45                                               HFD 2
# 47                                              EXT037
# 50                                              EXT146
# 51                                              EXT147
# 52                                              EXT148
# 55                                              EXT293
# 56                                              EXT294
# 62                Female High Fat Diet Pituitary 10 wk
# 64                  Male High Fat Diet Pituitary 10 wk
# 69           Female High Fat Diet Pituitary 15 wk rep1
# 70           Female High Fat Diet Pituitary 15 wk rep2
# 71             Male High Fat Diet Pituitary 15 wk rep1
# 72             Male High Fat Diet Pituitary 15 wk rep2
# 78                              GATA2cKO_Mouse3_snATAC
# 79                              GATA2cKO_Mouse7_snATAC
# 80                             GATA2cKO_Mouse17_snATAC
# 84                               GATA2cKO_Mouse3_snRNA
# 85                               GATA2cKO_Mouse7_snRNA
# 86                              GATA2cKO_Mouse17_snRNA
# 90                                    SF1KO_MaleMouse8
# 92                                             AX4days
# 93                                             AX48hrs
# 95                                             GX4days
# 102                  Sox9iresCreERT2/+;Sox2fl/+;p27-/-
# 103                           Sox9iresCreERT2/+;p27-/-
# 108                    pituitary gland, Hesx1Cre_dnRAR
# 110                                        Prop1 df/df
# 113                         HFD_pituitary scRNA-seq_01
# 114                         HFD_pituitary scRNA-seq_02
# 117                      IREPKO_pituitary scRNA-seq_01
# 118                      IREPKO_pituitary scRNA-seq_02
# 126                                   Pituitary_TpitHT
# 127                                   Pituitary_TpitKO
# 161                 p25OE pituitary, 40 week, scRNAseq
# 162                 p25OE pituitary, 14 week, scRNAseq
# 165                                             EXT331
# 166                                             EXT352
# 168                                    EXT356 organoid
# 169                                    EXT357 organoid
# 170                                    EXT358 organoid
# 171                                    EXT364 organoid
# 172  Gonadotrope-specific Acvr1b conditional knocko...
# 173  Gonadotrope-specific Acvr1b conditional knocko...
# 174  Gonadotrope-specific Acvr1b conditional knocko...
# 178  Gonadotrope-specific Tgfbr1 conditional knocko...
# 179  Gonadotrope-specific Tgfbr1 conditional knocko...
# 180  Gonadotrope-specific Tgfbr1 conditional knocko...
# 183  Two pooled e14.5 pituitary glands from C57BL6 ...
# 188  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant fe...
# 189  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant fe...
# 190  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant ma...
# 191  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant ma...
#
#                                             Conditions  Normal  \
# 32                                             mt/hGRF       0
# 41                                            stressed       0
# 44                                       high_fat_diet       0
# 45                                       high_fat_diet       0
# 47                          GHCre/+;R26iDTR/+ ablation       0
# 50                          GHCre/+;R26iDTR/+ ablation       0
# 51                          GHCre/+;R26iDTR/+ ablation       0
# 52                          GHCre/+;R26iDTR/+ ablation       0
# 55                          GHCre/+;R26iDTR/+ ablation       0
# 56                          GHCre/+;R26iDTR/+ ablation       0
# 62                                       high_fat_diet       0
# 64                                       high_fat_diet       0
# 69                                       high_fat_diet       0
# 70                                       high_fat_diet       0
# 71                                       high_fat_diet       0
# 72                                       high_fat_diet       0
# 78                                             GATAcKO       0
# 79                                             GATAcKO       0
# 80                                             GATAcKO       0
# 84                                             GATAcKO       0
# 85                                             GATAcKO       0
# 86                                             GATAcKO       0
# 90                                              SF1_KO       0
# 92                           adrenalectomy_sox9_sorted       0
# 93                           adrenalectomy_sox9_sorted       0
# 95                             gonadectomy_sox9_sorted       0
# 102                                               S2CK       0
# 103                                            P27NULL       0
# 108                                     Hesx1Cre_dnRAR       0
# 110                                        Prop1 df/df       0
# 113                                      high_fat_diet       0
# 114                                      high_fat_diet       0
# 117                                             IREPKO       0
# 118                                             IREPKO       0
# 126                                   Pituitary_TpitHT       0
# 127                                   Pituitary_TpitKO       0
# 161                                              p25OE       0
# 162                                              p25OE       0
# 165                         GHCre/+;R26iDTR/+ ablation       0
# 166                         GHCre/+;R26iDTR/+ ablation       0
# 168                                             normal       2
# 169                                             normal       2
# 170                                             normal       2
# 171                                             normal       2
# 172              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 173              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 174              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 178              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 179              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 180              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 183                                           Nxn -/-        0
# 188  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 189  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 190  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 191  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
#
#                       Background  Sorted                       Author  \
# 32                           CD1       0             Ho et al. (2020)
# 41                       C57BL/6       0          Lopez et al. (2021)
# 44                       C57BL/6       0  Ruggiero-Ruff et al. (2023)
# 45                       C57BL/6       0  Ruggiero-Ruff et al. (2023)
# 47                       C57BL/6       0      Vennekens et al. (2021)
# 50                       C57BL/6       0      Vennekens et al. (2021)
# 51                       C57BL/6       0      Vennekens et al. (2021)
# 52                       C57BL/6       0      Vennekens et al. (2021)
# 55                       C57BL/6       0        Laporte et al. (2022)
# 56                       C57BL/6       0        Laporte et al. (2022)
# 62                       FVB/Ant       0          Miles et al. (2023)
# 64                       FVB/Ant       0          Miles et al. (2023)
# 69                       FVB/Ant       0          Miles et al. (2023)
# 70                       FVB/Ant       0          Miles et al. (2023)
# 71                       FVB/Ant       0          Miles et al. (2023)
# 72                       FVB/Ant       0          Miles et al. (2023)
# 78                         mixed       0         Schang et al. (2022)
# 79                         mixed       0         Schang et al. (2022)
# 80                         mixed       0         Schang et al. (2022)
# 84                         mixed       0         Schang et al. (2022)
# 85                         mixed       0         Schang et al. (2022)
# 86                         mixed       0         Schang et al. (2022)
# 90            C57BL/6 x 129sv/ev       0            Lin et al. (2022)
# 92                       C57BL/6       1        Rizzoti et al. (2023)
# 93                       C57BL/6       1        Rizzoti et al. (2023)
# 95                       C57BL/6       1        Rizzoti et al. (2023)
# 102                      missing       0    Moncho-Amor et al. (2021)
# 103                      missing       0    Moncho-Amor et al. (2021)
# 108                      missing       0         Cheung et al. (2020)
# 110                      missing       0         Masser et al. (2024)
# 113                      C57BL/6       0           Qian et al. (2024)
# 114                      C57BL/6       0           Qian et al. (2024)
# 117                      missing       0           Qian et al. (2024)
# 118                      missing       0           Qian et al. (2024)
# 126                       Balb/c       0   Khetchoumian et al. (2024)
# 127                       Balb/c       0   Khetchoumian et al. (2024)
# 161    C57BL/6- B6;CBA-BiTg mice       0          Huang et al. (2024)
# 162    C57BL/6- B6;CBA-BiTg mice       0          Huang et al. (2024)
# 165                      C57BL/6       0     De Vriendt et al. (2025)
# 166                      C57BL/6       0     De Vriendt et al. (2025)
# 168                      C57BL/6       1     De Vriendt et al. (2025)
# 169                      C57BL/6       1     De Vriendt et al. (2025)
# 170                      C57BL/6       1     De Vriendt et al. (2025)
# 171                      C57BL/6       1     De Vriendt et al. (2025)
# 172         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 173         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 174         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 178  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 179  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 180  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 183                      C57BL/6       0     Brinkmeier et al. (2025)
# 188                      FVB/Ant       0          Miles et al. (2025)
# 189                      FVB/Ant       0          Miles et al. (2025)
# 190                      FVB/Ant       0          Miles et al. (2025)
# 191                      FVB/Ant       0          Miles et al. (2025)
#
#                             DOI              Age  ...  most_recent_workflow  \
# 32   10.1007/s13238-020-00705-x           8 week  ...                v_0.01
# 41       10.1126/sciadv.abe4497          10 week  ...                v_0.01
# 44       10.1210/endocr/bqad196          16 week  ...                v_0.01
# 45       10.1210/endocr/bqad196          16 week  ...                v_0.01
# 47      10.1073/pnas.2100052118       9-11 weeks  ...                v_0.01
# 50      10.1073/pnas.2100052118         14 month  ...                v_0.01
# 51      10.1073/pnas.2100052118         14 month  ...                v_0.01
# 52      10.1073/pnas.2100052118       9-11 weeks  ...                v_0.01
# 55          10.7554/eLife.75742           7 days  ...                v_0.01
# 56          10.7554/eLife.75742           7 days  ...                v_0.01
# 62       10.1210/endocr/bqad191          10 week  ...                v_0.01
# 64       10.1210/endocr/bqad191          10 week  ...                v_0.01
# 69       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 70       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 71       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 72       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 78    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 79    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 80    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 84    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 85    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 86    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 90       10.1210/endocr/bqac131      10-12 weeks  ...                v_0.01
# 92       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 93       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 95       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 102     10.1073/pnas.2017115118          3 month  ...                v_0.01
# 103     10.1073/pnas.2017115118          3 month  ...                v_0.01
# 108      10.1210/endocr/bqaa002               p4  ...                v_0.01
# 110      10.1210/jendso/bvae146               P4  ...                v_0.01
# 113  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 114  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 117  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 118  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 126     10.1073/pnas.2410269121          3 month  ...                v_0.01
# 127     10.1073/pnas.2410269121          3 month  ...                v_0.01
# 161   10.1016/j.neo.2024.101054               40  ...                v_0.01
# 162   10.1016/j.neo.2024.101054               14  ...                v_0.01
# 165  10.1016/j.isci.2024.111708      24-26 month  ...                v_0.01
# 166  10.1016/j.isci.2024.111708      24-26 month  ...                v_0.01
# 168  10.1016/j.isci.2024.111708       2-3 months  ...                v_0.01
# 169  10.1016/j.isci.2024.111708     10-15 months  ...                v_0.01
# 170  10.1016/j.isci.2024.111708        24 months  ...                v_0.01
# 171  10.1016/j.isci.2024.111708       1/4 months  ...                v_0.01
# 172     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 173     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 174     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 178     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 179     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 180     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 183         10.1093/hmg/ddaf032            e14.5  ...                v_0.01
# 188      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 189      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 190      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 191      10.1210/endocr/bqaf036        10 months  ...                v_0.01
#
#      n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core  \
# 32    1249.0             0.0          -1.0               NaN  1.0
# 41    4332.0             0.0           1.0            v_0.01  1.0
# 44    5297.0             0.0           1.0            v_0.01  1.0
# 45    6174.0             0.0           1.0            v_0.01  1.0
# 47    3463.0             0.0           1.0            v_0.01  1.0
# 50    2224.0             0.0           1.0            v_0.01  1.0
# 51    2320.0             0.0           1.0            v_0.01  1.0
# 52    2614.0             0.0           1.0            v_0.01  1.0
# 55    4585.0             0.0           1.0            v_0.01  1.0
# 56    5290.0             0.0           1.0            v_0.01  1.0
# 62    1348.0             0.0           1.0            v_0.01  1.0
# 64    1304.0             0.0           1.0            v_0.01  1.0
# 69     693.0             0.0          -1.0               NaN  1.0
# 70     566.0             0.0          -1.0               NaN  1.0
# 71     675.0             0.0           1.0            v_0.01  1.0
# 72    1372.0             0.0           1.0            v_0.01  1.0
# 78    2454.0             1.0           NaN               NaN  1.0
# 79    4445.0             1.0           NaN               NaN  1.0
# 80    3683.0             1.0           NaN               NaN  1.0
# 84    8428.0             0.0           NaN               NaN  1.0
# 85   10130.0             0.0           NaN               NaN  1.0
# 86    9052.0             0.0           NaN               NaN  1.0
# 90    2312.0             1.0           NaN               NaN  1.0
# 92    1457.0             0.0           1.0            v_0.01  1.0
# 93    3483.0             0.0           1.0            v_0.01  1.0
# 95    1016.0             0.0           1.0            v_0.01  1.0
# 102   3262.0             0.0           1.0            v_0.01  1.0
# 103   3762.0             0.0           1.0            v_0.01  1.0
# 108   4886.0             0.0           1.0            v_0.01  1.0
# 110   4321.0             0.0           1.0            v_0.01  1.0
# 113   2967.0             0.0           1.0            v_0.01  1.0
# 114   2982.0             0.0           1.0            v_0.01  1.0
# 117   3858.0             0.0           1.0            v_0.01  1.0
# 118   3851.0             0.0           1.0            v_0.01  1.0
# 126  13463.0             0.0           1.0            v_0.01  1.0
# 127  14912.0             0.0           1.0            v_0.01  1.0
# 161   6205.0             NaN           1.0            v_0.01  1.0
# 162   5457.0             NaN           1.0            v_0.01  1.0
# 165   3657.0             NaN           1.0            v_0.01  1.0
# 166   4506.0             NaN           1.0            v_0.01  1.0
# 168   5159.0             NaN           1.0               NaN  1.0
# 169   4861.0             NaN           1.0               NaN  1.0
# 170   2936.0             NaN           1.0               NaN  1.0
# 171   6805.0             NaN           1.0               NaN  1.0
# 172   5494.0             NaN           NaN               NaN  1.0
# 173  20469.0             NaN           NaN               NaN  1.0
# 174   6874.0             NaN           NaN               NaN  1.0
# 178   5314.0             NaN           NaN               NaN  1.0
# 179   1589.0             NaN           NaN               NaN  1.0
# 180   7270.0             NaN           NaN               NaN  1.0
# 183   4600.0             NaN           1.0            v_0.01  1.0
# 188   1064.0             NaN           1.0            v_0.01  1.0
# 189   2641.0             NaN           1.0            v_0.01  1.0
# 190    632.0             NaN           1.0            v_0.01  1.0
# 191    709.0             NaN           1.0            v_0.01  1.0
#
#                                                Notes 1 Notes 2  \
# 32                                                 NaN     NaN
# 41                                                 NaN     NaN
# 44                                                 NaN     NaN
# 45                                                 NaN     NaN
# 47              got fastq separately from arrayexpress     NaN
# 50              got fastq separately from arrayexpress     NaN
# 51              got fastq separately from arrayexpress     NaN
# 52              got fastq separately from arrayexpress     NaN
# 55   had to correct from v2 to v3 - Not actually mixed     NaN
# 56   had to correct from v2 to v3 - Not actually mixed     NaN
# 62                                                 NaN     NaN
# 64                                                 NaN     NaN
# 69                                                 NaN     NaN
# 70                                                 NaN     NaN
# 71                                                 NaN     NaN
# 72                                                 NaN     NaN
# 78                                                 NaN     NaN
# 79                                                 NaN     NaN
# 80                                                 NaN     NaN
# 84                                                 NaN     NaN
# 85                                                 NaN     NaN
# 86                                                 NaN     NaN
# 90                                                 NaN     NaN
# 92                            Incorrectnly v3 in paper     NaN
# 93                                                 NaN     NaN
# 95                                                 NaN     NaN
# 102                     intermediate lobe only; no sex     NaN
# 103  intermediate lobe only; no sex - probably bit ...     NaN
# 108                     fastq file is weird need bam!!     NaN
# 110                                V2 actually, not V3     NaN
# 113                                                NaN     NaN
# 114                                                NaN     NaN
# 117                                                NaN     NaN
# 118                                                NaN     NaN
# 126                                                NaN     NaN
# 127                                                NaN     NaN
# 161                            Incorrectly v3 in paper     NaN
# 162                              Incorrectly v2 on GEO     NaN
# 165                                                NaN     NaN
# 166                                                NaN     NaN
# 168                                                NaN     NaN
# 169                                                NaN     NaN
# 170                                                NaN     NaN
# 171                                                NaN     NaN
# 172                                                NaN     NaN
# 173                                                NaN     NaN
# 174                                                NaN     NaN
# 178                                                NaN     NaN
# 179                                                NaN     NaN
# 180                                                NaN     NaN
# 183                                        missing sex     NaN
# 188  somewhat unclear, but the text suggests they w...     NaN
# 189  somewhat unclear, but the text suggests they w...     NaN
# 190  somewhat unclear, but the text suggests they w...     NaN
# 191  somewhat unclear, but the text suggests they w...     NaN
#
#      Study_Seurat_version_int Study_CR_version_int
# 32                          3                 <NA>
# 41                          1                    2
# 44                          4                    6
# 45                          4                    6
# 47                          3                    3
# 50                          3                    3
# 51                          3                    3
# 52                          3                    3
# 55                          3                    3
# 56                          3                    3
# 62                       <NA>                    3
# 64                       <NA>                    3
# 69                       <NA>                    3
# 70                       <NA>                    3
# 71                       <NA>                    3
# 72                       <NA>                    3
# 78                       <NA>                    1
# 79                       <NA>                    1
# 80                       <NA>                    1
# 84                       <NA>                    5
# 85                       <NA>                    5
# 86                       <NA>                    5
# 90                       <NA>                    1
# 92                          3                    3
# 93                          3                    3
# 95                          3                    3
# 102                         3                    3
# 103                         3                    3
# 108                         3                    3
# 110                         3                    3
# 113                         4                    0
# 114                         4                    0
# 117                         4                    0
# 118                         4                    0
# 126                         3                    5
# 127                         3                    5
# 161                         4                    3
# 162                         4                    3
# 165                         4                    6
# 166                         4                    6
# 168                         4                    6
# 169                         4                    6
# 170                         4                    6
# 171                         4                    6
# 172                      <NA>                    7
# 173                      <NA>                    7
# 174                      <NA>                    7
# 178                      <NA>                    7
# 179                      <NA>                    7
# 180                      <NA>                    7
# 183                         4                    7
# 188                      <NA>                    3
# 189                      <NA>                    3
# 190                      <NA>                    3
# 191                      <NA>                    3
#
# [55 rows x 43 columns]

# %%
#which samples have n_cells > 0
df[df["n_cells"]<300]
# Out:
#                   GEO            SRA_ID                Name Conditions  \
# 29         GSM4026477        SRX6699503     PP2 (scRNA-Seq)     normal
# 36         GSM4399749        SRX7874743  WT-8wk-0324-female     normal
# 37         GSM4399750        SRX7874744    WT-8wk-0324-male     normal
# 203   069_NODJ_10M_01   069_NODJ_10M_01                 NaN     normal
# 238  094_CASTJ_10F_01  094_CASTJ_10F_01                 NaN     normal
# 244   062_WSBJ_10F_01   062_WSBJ_10F_01                 NaN     normal
#
#      Normal Background  Sorted                 Author  \
# 29        1    C57BL/6       1     Chen et al. (2018)
# 36        1        CD1       0       Ho et al. (2020)
# 37        1        CD1       0       Ho et al. (2020)
# 203       1       NODJ       0  Rebboah et al. (2025)
# 238       1      CASTJ       0  Rebboah et al. (2025)
# 244       1       WSBJ       0  Rebboah et al. (2025)
#
#                              DOI       Age  ...  most_recent_workflow n_cells  \
# 29   10.1523/ENEURO.0345-19.2019  3 months  ...                v_0.01   266.0
# 36    10.1007/s13238-020-00705-x    8 week  ...                v_0.01   213.0
# 37    10.1007/s13238-020-00705-x    8 week  ...                v_0.01    65.0
# 203                          NaN        72  ...                v_0.01   151.0
# 238                          NaN        69  ...                v_0.01   134.0
# 244                          NaN        69  ...                v_0.01    23.0
#
#      processed_atac passed_qc_tcc  tcc_pseudobulked Core Notes 1  \
# 29              0.0          -1.0               NaN  1.0     NaN
# 36              0.0          -1.0               NaN  1.0     NaN
# 37              0.0          -1.0               NaN  1.0     NaN
# 203             NaN           NaN               NaN  0.0     NaN
# 238             NaN           NaN               NaN  0.0     NaN
# 244             NaN           NaN               NaN  0.0     NaN
#
#                            Notes 2  Study_Seurat_version_int  \
# 29                             NaN                         2
# 36                             NaN                         3
# 37                             NaN                         3
# 203                            NaN                      <NA>
# 238                            NaN                      <NA>
# 244  Pituitary seems to be missing                      <NA>
#
#     Study_CR_version_int
# 29                     2
# 36                  <NA>
# 37                  <NA>
# 203                 <NA>
# 238                 <NA>
# 244                 <NA>
#
# [6 rows x 43 columns]

# %%
df['10X version'].value_counts()
# Out:
# 10X version
# 10XV3              126
# PARSE_WT_MegaV2     65
# 10XV1               37
# 10XV2               30
# DROPSEQ              8
# Name: count, dtype: int64

# %%
df
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [267 rows x 43 columns]

# %%
df[(df["Normal"]==0) & ~(df["Author"].str.startswith("Rebboah"))]
# Out:
#              GEO       SRA_ID  \
# 32    GSM4399745   SRX7874739
# 41    GSM4914025   SRX9528565
# 44    GSM7679946  SRX21241800
# 45    GSM7679947  SRX21241801
# 47    ERX4978538   ERX4978538
# 50    ERX4978541   ERX4978541
# 51    ERX4978542   ERX4978542
# 52    ERX4978543   ERX4978543
# 55    ERX7593482   ERX7593482
# 56    ERX7593483   ERX7593483
# 62    GSM7821514  SRX21986106
# 64    GSM7821516  SRX21986108
# 69    GSM7821521  SRX21986113
# 70    GSM7821522  SRX21986114
# 71    GSM7821523  SRX21986115
# 72    GSM7821524  SRX21986116
# 78    GSM5712761  SRX13293487
# 79    GSM5712762  SRX13293488
# 80    GSM5712763  SRX13293489
# 84    GSM5712741  SRX13290060
# 85    GSM5712742  SRX13290061
# 86    GSM5712743  SRX13290062
# 90    GSM5959924  SRX14495688
# 92    GSM6723959  SRX18224105
# 93    GSM6723960  SRX18224106
# 95    GSM6723962  SRX18224108
# 102   GSM4597452   SRX8497093
# 103   GSM4597453   SRX8497094
# 108   GSM4219538   SRX7377166
# 110   GSM8435091  SRX25532499
# 113   GSM8187332  SRX24151434
# 114   GSM8187333  SRX24151435
# 117   GSM8187336  SRX24151438
# 118   GSM8187337  SRX24151439
# 126   GSM7102843  SRX19698101
# 127   GSM7102844  SRX19698100
# 161   GSM6845275  SRX18716673
# 162   GSM6845276  SRX18716674
# 165  ERX13202613  ERX13202613
# 166  ERX13202614  ERX13202614
# 172   GSM8464638  SRX25736219
# 173   GSM8464639  SRX25736220
# 174   GSM8464640  SRX25736221
# 178   GSM8464644  SRX25736225
# 179   GSM8464645  SRX25736226
# 180   GSM8464646  SRX25736227
# 183   GSM8628052  SRX26708357
# 188   GSM8499073  SRX25982298
# 189   GSM8499074  SRX25982301
# 190   GSM8499075  SRX25982300
# 191   GSM8499076  SRX25982299
#
#                                                   Name  \
# 32                       mt/hGRF transgenic-8wk-female
# 41                                    Pituitary_Stress
# 44                                               HFD 1
# 45                                               HFD 2
# 47                                              EXT037
# 50                                              EXT146
# 51                                              EXT147
# 52                                              EXT148
# 55                                              EXT293
# 56                                              EXT294
# 62                Female High Fat Diet Pituitary 10 wk
# 64                  Male High Fat Diet Pituitary 10 wk
# 69           Female High Fat Diet Pituitary 15 wk rep1
# 70           Female High Fat Diet Pituitary 15 wk rep2
# 71             Male High Fat Diet Pituitary 15 wk rep1
# 72             Male High Fat Diet Pituitary 15 wk rep2
# 78                              GATA2cKO_Mouse3_snATAC
# 79                              GATA2cKO_Mouse7_snATAC
# 80                             GATA2cKO_Mouse17_snATAC
# 84                               GATA2cKO_Mouse3_snRNA
# 85                               GATA2cKO_Mouse7_snRNA
# 86                              GATA2cKO_Mouse17_snRNA
# 90                                    SF1KO_MaleMouse8
# 92                                             AX4days
# 93                                             AX48hrs
# 95                                             GX4days
# 102                  Sox9iresCreERT2/+;Sox2fl/+;p27-/-
# 103                           Sox9iresCreERT2/+;p27-/-
# 108                    pituitary gland, Hesx1Cre_dnRAR
# 110                                        Prop1 df/df
# 113                         HFD_pituitary scRNA-seq_01
# 114                         HFD_pituitary scRNA-seq_02
# 117                      IREPKO_pituitary scRNA-seq_01
# 118                      IREPKO_pituitary scRNA-seq_02
# 126                                   Pituitary_TpitHT
# 127                                   Pituitary_TpitKO
# 161                 p25OE pituitary, 40 week, scRNAseq
# 162                 p25OE pituitary, 14 week, scRNAseq
# 165                                             EXT331
# 166                                             EXT352
# 172  Gonadotrope-specific Acvr1b conditional knocko...
# 173  Gonadotrope-specific Acvr1b conditional knocko...
# 174  Gonadotrope-specific Acvr1b conditional knocko...
# 178  Gonadotrope-specific Tgfbr1 conditional knocko...
# 179  Gonadotrope-specific Tgfbr1 conditional knocko...
# 180  Gonadotrope-specific Tgfbr1 conditional knocko...
# 183  Two pooled e14.5 pituitary glands from C57BL6 ...
# 188  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant fe...
# 189  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant fe...
# 190  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant ma...
# 191  FVB.129P2-Pde6b + Tyr c-ch/AntJ LEPR mutant ma...
#
#                                             Conditions  Normal  \
# 32                                             mt/hGRF       0
# 41                                            stressed       0
# 44                                       high_fat_diet       0
# 45                                       high_fat_diet       0
# 47                          GHCre/+;R26iDTR/+ ablation       0
# 50                          GHCre/+;R26iDTR/+ ablation       0
# 51                          GHCre/+;R26iDTR/+ ablation       0
# 52                          GHCre/+;R26iDTR/+ ablation       0
# 55                          GHCre/+;R26iDTR/+ ablation       0
# 56                          GHCre/+;R26iDTR/+ ablation       0
# 62                                       high_fat_diet       0
# 64                                       high_fat_diet       0
# 69                                       high_fat_diet       0
# 70                                       high_fat_diet       0
# 71                                       high_fat_diet       0
# 72                                       high_fat_diet       0
# 78                                             GATAcKO       0
# 79                                             GATAcKO       0
# 80                                             GATAcKO       0
# 84                                             GATAcKO       0
# 85                                             GATAcKO       0
# 86                                             GATAcKO       0
# 90                                              SF1_KO       0
# 92                           adrenalectomy_sox9_sorted       0
# 93                           adrenalectomy_sox9_sorted       0
# 95                             gonadectomy_sox9_sorted       0
# 102                                               S2CK       0
# 103                                            P27NULL       0
# 108                                     Hesx1Cre_dnRAR       0
# 110                                        Prop1 df/df       0
# 113                                      high_fat_diet       0
# 114                                      high_fat_diet       0
# 117                                             IREPKO       0
# 118                                             IREPKO       0
# 126                                   Pituitary_TpitHT       0
# 127                                   Pituitary_TpitKO       0
# 161                                              p25OE       0
# 162                                              p25OE       0
# 165                         GHCre/+;R26iDTR/+ ablation       0
# 166                         GHCre/+;R26iDTR/+ ablation       0
# 172              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 173              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 174              Acvr1bflox/flox;GnrhrCre/+ (Alk4-cKO)       0
# 178              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 179              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 180              Tgfbr1flox/flox;GnrhrCre/+ (Alk5-cKO)       0
# 183                                           Nxn -/-        0
# 188  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 189  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 190  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
# 191  FVB.129P2-Pde6b + Tyr c-ch/AntJ; Tg(Gh1-cre)bK...       0
#
#                       Background  Sorted                       Author  \
# 32                           CD1       0             Ho et al. (2020)
# 41                       C57BL/6       0          Lopez et al. (2021)
# 44                       C57BL/6       0  Ruggiero-Ruff et al. (2023)
# 45                       C57BL/6       0  Ruggiero-Ruff et al. (2023)
# 47                       C57BL/6       0      Vennekens et al. (2021)
# 50                       C57BL/6       0      Vennekens et al. (2021)
# 51                       C57BL/6       0      Vennekens et al. (2021)
# 52                       C57BL/6       0      Vennekens et al. (2021)
# 55                       C57BL/6       0        Laporte et al. (2022)
# 56                       C57BL/6       0        Laporte et al. (2022)
# 62                       FVB/Ant       0          Miles et al. (2023)
# 64                       FVB/Ant       0          Miles et al. (2023)
# 69                       FVB/Ant       0          Miles et al. (2023)
# 70                       FVB/Ant       0          Miles et al. (2023)
# 71                       FVB/Ant       0          Miles et al. (2023)
# 72                       FVB/Ant       0          Miles et al. (2023)
# 78                         mixed       0         Schang et al. (2022)
# 79                         mixed       0         Schang et al. (2022)
# 80                         mixed       0         Schang et al. (2022)
# 84                         mixed       0         Schang et al. (2022)
# 85                         mixed       0         Schang et al. (2022)
# 86                         mixed       0         Schang et al. (2022)
# 90            C57BL/6 x 129sv/ev       0            Lin et al. (2022)
# 92                       C57BL/6       1        Rizzoti et al. (2023)
# 93                       C57BL/6       1        Rizzoti et al. (2023)
# 95                       C57BL/6       1        Rizzoti et al. (2023)
# 102                      missing       0    Moncho-Amor et al. (2021)
# 103                      missing       0    Moncho-Amor et al. (2021)
# 108                      missing       0         Cheung et al. (2020)
# 110                      missing       0         Masser et al. (2024)
# 113                      C57BL/6       0           Qian et al. (2024)
# 114                      C57BL/6       0           Qian et al. (2024)
# 117                      missing       0           Qian et al. (2024)
# 118                      missing       0           Qian et al. (2024)
# 126                       Balb/c       0   Khetchoumian et al. (2024)
# 127                       Balb/c       0   Khetchoumian et al. (2024)
# 161    C57BL/6- B6;CBA-BiTg mice       0          Huang et al. (2024)
# 162    C57BL/6- B6;CBA-BiTg mice       0          Huang et al. (2024)
# 165                      C57BL/6       0     De Vriendt et al. (2025)
# 166                      C57BL/6       0     De Vriendt et al. (2025)
# 172         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 173         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 174         129/SvJ and C57BL/6J       0         Ongaro et al. (2025)
# 178  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 179  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 180  129/SvJ/129S6/SvEv/C57BL/6J       0         Ongaro et al. (2025)
# 183                      C57BL/6       0     Brinkmeier et al. (2025)
# 188                      FVB/Ant       0          Miles et al. (2025)
# 189                      FVB/Ant       0          Miles et al. (2025)
# 190                      FVB/Ant       0          Miles et al. (2025)
# 191                      FVB/Ant       0          Miles et al. (2025)
#
#                             DOI              Age  ...  most_recent_workflow  \
# 32   10.1007/s13238-020-00705-x           8 week  ...                v_0.01
# 41       10.1126/sciadv.abe4497          10 week  ...                v_0.01
# 44       10.1210/endocr/bqad196          16 week  ...                v_0.01
# 45       10.1210/endocr/bqad196          16 week  ...                v_0.01
# 47      10.1073/pnas.2100052118       9-11 weeks  ...                v_0.01
# 50      10.1073/pnas.2100052118         14 month  ...                v_0.01
# 51      10.1073/pnas.2100052118         14 month  ...                v_0.01
# 52      10.1073/pnas.2100052118       9-11 weeks  ...                v_0.01
# 55          10.7554/eLife.75742           7 days  ...                v_0.01
# 56          10.7554/eLife.75742           7 days  ...                v_0.01
# 62       10.1210/endocr/bqad191          10 week  ...                v_0.01
# 64       10.1210/endocr/bqad191          10 week  ...                v_0.01
# 69       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 70       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 71       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 72       10.1210/endocr/bqad191          15 week  ...                v_0.01
# 78    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 79    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 80    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 84    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 85    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 86    10.1016/j.jbc.2022.102072       8-10 weeks  ...                v_0.01
# 90       10.1210/endocr/bqac131      10-12 weeks  ...                v_0.01
# 92       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 93       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 95       10.1126/sciadv.adf6911    7 to 10 w-old  ...                v_0.01
# 102     10.1073/pnas.2017115118          3 month  ...                v_0.01
# 103     10.1073/pnas.2017115118          3 month  ...                v_0.01
# 108      10.1210/endocr/bqaa002               p4  ...                v_0.01
# 110      10.1210/jendso/bvae146               P4  ...                v_0.01
# 113  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 114  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 117  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 118  10.1016/j.cmet.2024.04.014      3+16 weeks?  ...                v_0.01
# 126     10.1073/pnas.2410269121          3 month  ...                v_0.01
# 127     10.1073/pnas.2410269121          3 month  ...                v_0.01
# 161   10.1016/j.neo.2024.101054               40  ...                v_0.01
# 162   10.1016/j.neo.2024.101054               14  ...                v_0.01
# 165  10.1016/j.isci.2024.111708      24-26 month  ...                v_0.01
# 166  10.1016/j.isci.2024.111708      24-26 month  ...                v_0.01
# 172     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 173     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 174     10.1126/science.adi4736  12-13 weeks old  ...                v_0.01
# 178     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 179     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 180     10.1126/science.adi4736    8-9 weeks old  ...                v_0.01
# 183         10.1093/hmg/ddaf032            e14.5  ...                v_0.01
# 188      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 189      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 190      10.1210/endocr/bqaf036        10 months  ...                v_0.01
# 191      10.1210/endocr/bqaf036        10 months  ...                v_0.01
#
#      n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core  \
# 32    1249.0             0.0          -1.0               NaN  1.0
# 41    4332.0             0.0           1.0            v_0.01  1.0
# 44    5297.0             0.0           1.0            v_0.01  1.0
# 45    6174.0             0.0           1.0            v_0.01  1.0
# 47    3463.0             0.0           1.0            v_0.01  1.0
# 50    2224.0             0.0           1.0            v_0.01  1.0
# 51    2320.0             0.0           1.0            v_0.01  1.0
# 52    2614.0             0.0           1.0            v_0.01  1.0
# 55    4585.0             0.0           1.0            v_0.01  1.0
# 56    5290.0             0.0           1.0            v_0.01  1.0
# 62    1348.0             0.0           1.0            v_0.01  1.0
# 64    1304.0             0.0           1.0            v_0.01  1.0
# 69     693.0             0.0          -1.0               NaN  1.0
# 70     566.0             0.0          -1.0               NaN  1.0
# 71     675.0             0.0           1.0            v_0.01  1.0
# 72    1372.0             0.0           1.0            v_0.01  1.0
# 78    2454.0             1.0           NaN               NaN  1.0
# 79    4445.0             1.0           NaN               NaN  1.0
# 80    3683.0             1.0           NaN               NaN  1.0
# 84    8428.0             0.0           NaN               NaN  1.0
# 85   10130.0             0.0           NaN               NaN  1.0
# 86    9052.0             0.0           NaN               NaN  1.0
# 90    2312.0             1.0           NaN               NaN  1.0
# 92    1457.0             0.0           1.0            v_0.01  1.0
# 93    3483.0             0.0           1.0            v_0.01  1.0
# 95    1016.0             0.0           1.0            v_0.01  1.0
# 102   3262.0             0.0           1.0            v_0.01  1.0
# 103   3762.0             0.0           1.0            v_0.01  1.0
# 108   4886.0             0.0           1.0            v_0.01  1.0
# 110   4321.0             0.0           1.0            v_0.01  1.0
# 113   2967.0             0.0           1.0            v_0.01  1.0
# 114   2982.0             0.0           1.0            v_0.01  1.0
# 117   3858.0             0.0           1.0            v_0.01  1.0
# 118   3851.0             0.0           1.0            v_0.01  1.0
# 126  13463.0             0.0           1.0            v_0.01  1.0
# 127  14912.0             0.0           1.0            v_0.01  1.0
# 161   6205.0             NaN           1.0            v_0.01  1.0
# 162   5457.0             NaN           1.0            v_0.01  1.0
# 165   3657.0             NaN           1.0            v_0.01  1.0
# 166   4506.0             NaN           1.0            v_0.01  1.0
# 172   5494.0             NaN           NaN               NaN  1.0
# 173  20469.0             NaN           NaN               NaN  1.0
# 174   6874.0             NaN           NaN               NaN  1.0
# 178   5314.0             NaN           NaN               NaN  1.0
# 179   1589.0             NaN           NaN               NaN  1.0
# 180   7270.0             NaN           NaN               NaN  1.0
# 183   4600.0             NaN           1.0            v_0.01  1.0
# 188   1064.0             NaN           1.0            v_0.01  1.0
# 189   2641.0             NaN           1.0            v_0.01  1.0
# 190    632.0             NaN           1.0            v_0.01  1.0
# 191    709.0             NaN           1.0            v_0.01  1.0
#
#                                                Notes 1 Notes 2  \
# 32                                                 NaN     NaN
# 41                                                 NaN     NaN
# 44                                                 NaN     NaN
# 45                                                 NaN     NaN
# 47              got fastq separately from arrayexpress     NaN
# 50              got fastq separately from arrayexpress     NaN
# 51              got fastq separately from arrayexpress     NaN
# 52              got fastq separately from arrayexpress     NaN
# 55   had to correct from v2 to v3 - Not actually mixed     NaN
# 56   had to correct from v2 to v3 - Not actually mixed     NaN
# 62                                                 NaN     NaN
# 64                                                 NaN     NaN
# 69                                                 NaN     NaN
# 70                                                 NaN     NaN
# 71                                                 NaN     NaN
# 72                                                 NaN     NaN
# 78                                                 NaN     NaN
# 79                                                 NaN     NaN
# 80                                                 NaN     NaN
# 84                                                 NaN     NaN
# 85                                                 NaN     NaN
# 86                                                 NaN     NaN
# 90                                                 NaN     NaN
# 92                            Incorrectnly v3 in paper     NaN
# 93                                                 NaN     NaN
# 95                                                 NaN     NaN
# 102                     intermediate lobe only; no sex     NaN
# 103  intermediate lobe only; no sex - probably bit ...     NaN
# 108                     fastq file is weird need bam!!     NaN
# 110                                V2 actually, not V3     NaN
# 113                                                NaN     NaN
# 114                                                NaN     NaN
# 117                                                NaN     NaN
# 118                                                NaN     NaN
# 126                                                NaN     NaN
# 127                                                NaN     NaN
# 161                            Incorrectly v3 in paper     NaN
# 162                              Incorrectly v2 on GEO     NaN
# 165                                                NaN     NaN
# 166                                                NaN     NaN
# 172                                                NaN     NaN
# 173                                                NaN     NaN
# 174                                                NaN     NaN
# 178                                                NaN     NaN
# 179                                                NaN     NaN
# 180                                                NaN     NaN
# 183                                        missing sex     NaN
# 188  somewhat unclear, but the text suggests they w...     NaN
# 189  somewhat unclear, but the text suggests they w...     NaN
# 190  somewhat unclear, but the text suggests they w...     NaN
# 191  somewhat unclear, but the text suggests they w...     NaN
#
#      Study_Seurat_version_int Study_CR_version_int
# 32                          3                 <NA>
# 41                          1                    2
# 44                          4                    6
# 45                          4                    6
# 47                          3                    3
# 50                          3                    3
# 51                          3                    3
# 52                          3                    3
# 55                          3                    3
# 56                          3                    3
# 62                       <NA>                    3
# 64                       <NA>                    3
# 69                       <NA>                    3
# 70                       <NA>                    3
# 71                       <NA>                    3
# 72                       <NA>                    3
# 78                       <NA>                    1
# 79                       <NA>                    1
# 80                       <NA>                    1
# 84                       <NA>                    5
# 85                       <NA>                    5
# 86                       <NA>                    5
# 90                       <NA>                    1
# 92                          3                    3
# 93                          3                    3
# 95                          3                    3
# 102                         3                    3
# 103                         3                    3
# 108                         3                    3
# 110                         3                    3
# 113                         4                    0
# 114                         4                    0
# 117                         4                    0
# 118                         4                    0
# 126                         3                    5
# 127                         3                    5
# 161                         4                    3
# 162                         4                    3
# 165                         4                    6
# 166                         4                    6
# 172                      <NA>                    7
# 173                      <NA>                    7
# 174                      <NA>                    7
# 178                      <NA>                    7
# 179                      <NA>                    7
# 180                      <NA>                    7
# 183                         4                    7
# 188                      <NA>                    3
# 189                      <NA>                    3
# 190                      <NA>                    3
# 191                      <NA>                    3
#
# [51 rows x 43 columns]

# %%
authors1 = df[(df["Normal"]==1)]['Author'].unique()

# %%
authors2 = df['Author'].unique()

# %%
#which authors2 not in authors1
[x for x in authors2 if x not in authors1]
# Out:
# ['Brinkmeier et al. (2025)']

# %%
#df where Author doesnt start with Rebboah
print(df[~(df["Author"].str.startswith("Rebboah"))].shape)
#print where not Rebboah and Normal == 1
print(df[(df["Normal"]==1) & ~(df["Author"].str.startswith("Rebboah"))].shape)
# Out:
# (202, 43)
# (147, 43)

# %%
df
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [267 rows x 43 columns]

# %%
df[df["n_cells"].isna()]
# Out:
#                   GEO            SRA_ID Name Conditions  Normal Background  \
# 200   066_NODJ_10F_01   066_NODJ_10F_01  NaN     normal       1       NODJ
# 214     032_AJ_10F_01     032_AJ_10F_01  NaN     normal       1         AJ
# 232  086_CASTJ_10F_01  086_CASTJ_10F_01  NaN     normal       1      CASTJ
# 242   060_WSBJ_10F_01   060_WSBJ_10F_01  NaN     normal       1       WSBJ
# 246   096_WSBJ_10F_01   096_WSBJ_10F_01  NaN     normal       1       WSBJ
#
#      Sorted                 Author  DOI Age  ...  most_recent_workflow  \
# 200       0  Rebboah et al. (2025)  NaN  72  ...                   NaN
# 214       0  Rebboah et al. (2025)  NaN  69  ...                   NaN
# 232       0  Rebboah et al. (2025)  NaN  69  ...                   NaN
# 242       0  Rebboah et al. (2025)  NaN  69  ...                   NaN
# 246       0  Rebboah et al. (2025)  NaN  69  ...                   NaN
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core Notes 1  \
# 200     NaN             NaN           NaN               NaN  0.0     NaN
# 214     NaN             NaN           NaN               NaN  0.0     NaN
# 232     NaN             NaN           NaN               NaN  0.0     NaN
# 242     NaN             NaN           NaN               NaN  0.0     NaN
# 246     NaN             NaN           NaN               NaN  0.0     NaN
#
#                            Notes 2  Study_Seurat_version_int  \
# 200                            NaN                      <NA>
# 214                            NaN                      <NA>
# 232                            NaN                      <NA>
# 242  Pituitary seems to be missing                      <NA>
# 246  Pituitary seems to be missing                      <NA>
#
#     Study_CR_version_int
# 200                 <NA>
# 214                 <NA>
# 232                 <NA>
# 242                 <NA>
# 246                 <NA>
#
# [5 rows x 43 columns]

# %%
df
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [267 rows x 43 columns]

# %%
#print where n_cells > 300
df[df["n_cells"]>300]
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
# 266  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
# 266       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
# 266                         NaN       4 days  ...                v_0.01
#
#     n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core      Notes 1  \
# 0    1278.0             0.0           1.0            v_0.01  1.0          NaN
# 1    8236.0             0.0           1.0            v_0.01  1.0          NaN
# 2    7092.0             0.0           1.0            v_0.01  1.0          NaN
# 3    1755.0             0.0           1.0            v_0.01  1.0          NaN
# 4     416.0             0.0           1.0            v_0.01  1.0          NaN
# ..      ...             ...           ...               ...  ...          ...
# 262  7710.0             NaN           NaN               NaN  1.0  missing sex
# 263  7736.0             NaN           NaN               NaN  1.0  missing sex
# 264  6507.0             NaN           NaN               NaN  1.0  missing sex
# 265  2451.0             NaN           NaN               NaN  NaN          NaN
# 266  2124.0             NaN           NaN               NaN  NaN          NaN
#
#     Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0       NaN                         3                    3
# 1       NaN                         3                    3
# 2       NaN                         3                    3
# 3       NaN                         3                    3
# 4       NaN                         3                    3
# ..      ...                       ...                  ...
# 262     NaN                      <NA>                    6
# 263     NaN                      <NA>                    6
# 264     NaN                      <NA>                    6
# 265     NaN                      <NA>                 <NA>
# 266     NaN                      <NA>                 <NA>
#
# [256 rows x 43 columns]

# %%
df[(df["n_cells"]>300)&(df["Author"]!="Kover et al. (2025)")]["n_cells"].sum()
# Out:
# np.float64(1133668.0)

# %%
df[(df["10X version"]=="PARSE_WT_MegaV2")&(df["n_cells"]>300)&(df["Author"]!="Kover et al. (2025)")]["n_cells"].sum()
# Out:
# np.float64(112754.0)

# %%
df[(df["10X version"]!="PARSE_WT_MegaV2")&(df["n_cells"]>300)&(df["Author"]!="Kover et al. (2025)")]["n_cells"].sum()
# Out:
# np.float64(1020914.0)

# %%
df[(df["n_cells"]>300)]["n_cells"].sum()
# Out:
# np.float64(1138243.0)

# %%
df[(df["10X version"]=="PARSE_WT_MegaV2")&(df["n_cells"]>300)]["n_cells"].sum()
# Out:
# np.float64(112754.0)

# %%
df[(df["10X version"]!="PARSE_WT_MegaV2")&(df["n_cells"]>300)]["n_cells"].sum()
# Out:
# np.float64(1025489.0)

# %%
# Out:
# np.float64(112754.0)

# %%
#rna wild type samples
df[(df["Normal"]==1) & (df["Modality"].isin(["sc","sn","multi_rna"]))]
# Out:
#             GEO       SRA_ID                                  Name Conditions  \
# 0    GSM4594333   SRX8489818                           M-Pituitary     normal
# 1    GSM4594334   SRX8489819                            FM_Pit_1-1     normal
# 2    GSM4594335   SRX8489820                            FM_Pit_1-2     normal
# 3    GSM4594336   SRX8489821                            MM_Pit_4-1     normal
# 4    GSM4594337   SRX8489822                            MM_Pit_1v2     normal
# ..          ...          ...                                   ...        ...
# 261  GSM7663099  SRX21168593  Pituitary, young, sample1, scRNA-seq     normal
# 262  GSM7663100  SRX21168594   Pituitary, aged, sample1, scRNA-seq     normal
# 263  GSM7663101  SRX21168595  Pituitary, young, sample2, scRNA-seq     normal
# 264  GSM7663102  SRX21168596   Pituitary, aged, sample2, scRNA-seq     normal
# 265  MMP3-CONT1   MMP3-CONT1                        Pituitary_ctrl     normal
#
#      Normal Background  Sorted                      Author  \
# 0         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 1         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 2         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 3         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# 4         1    C57BL/6       0  Ruf-Zamojski et al. (2021)
# ..      ...        ...     ...                         ...
# 261       1    C57BL/6       0           Wei et al. (2025)
# 262       1    C57BL/6       0           Wei et al. (2025)
# 263       1    C57BL/6       0           Wei et al. (2025)
# 264       1    C57BL/6       0           Wei et al. (2025)
# 265       1    C57BL/6       0         Kover et al. (2025)
#
#                             DOI          Age  ...  most_recent_workflow  \
# 0    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 1    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 2    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 3    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# 4    10.1038/s41467-021-22859-w  10-12 weeks  ...                v_0.01
# ..                          ...          ...  ...                   ...
# 261                         NaN     6 months  ...                v_0.01
# 262                         NaN    24 months  ...                v_0.01
# 263                         NaN     6 months  ...                v_0.01
# 264                         NaN    24 months  ...                v_0.01
# 265                         NaN       4 days  ...                v_0.01
#
#      n_cells  processed_atac passed_qc_tcc  tcc_pseudobulked Core  \
# 0     1278.0             0.0           1.0            v_0.01  1.0
# 1     8236.0             0.0           1.0            v_0.01  1.0
# 2     7092.0             0.0           1.0            v_0.01  1.0
# 3     1755.0             0.0           1.0            v_0.01  1.0
# 4      416.0             0.0           1.0            v_0.01  1.0
# ..       ...             ...           ...               ...  ...
# 261  10116.0             NaN           NaN               NaN  1.0
# 262   7710.0             NaN           NaN               NaN  1.0
# 263   7736.0             NaN           NaN               NaN  1.0
# 264   6507.0             NaN           NaN               NaN  1.0
# 265   2451.0             NaN           NaN               NaN  NaN
#
#          Notes 1 Notes 2  Study_Seurat_version_int Study_CR_version_int
# 0            NaN     NaN                         3                    3
# 1            NaN     NaN                         3                    3
# 2            NaN     NaN                         3                    3
# 3            NaN     NaN                         3                    3
# 4            NaN     NaN                         3                    3
# ..           ...     ...                       ...                  ...
# 261  missing sex     NaN                      <NA>                    6
# 262  missing sex     NaN                      <NA>                    6
# 263  missing sex     NaN                      <NA>                    6
# 264  missing sex     NaN                      <NA>                    6
# 265          NaN     NaN                      <NA>                 <NA>
#
# [177 rows x 43 columns]
